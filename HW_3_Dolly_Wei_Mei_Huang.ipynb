# %% [markdown]
# <a href="https://colab.research.google.com/github/dollytwn/nyu-python-public-policy/blob/master/HW_3_Dolly_Wei_Mei_Huang.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive

# %%
# You can use pd.set_option() to make sure you see all the rows and columns in your dataframe
pd.set_option('display.max_columns', None)  # or 1000
pd.set_option('display.max_rows', None)  # or 1000

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/My Drive/Data for Python/cleaned_311_data_hw3.csv', header='infer')

# %%
set(df.complaint_type)
# Out:
# {'Bridge Condition',
#  'Broken Parking Meter',
#  'Bus Stop Shelter Complaint',
#  'Graffiti',
#  'Highway Condition',
#  'Maintenance or Facility',
#  'Public Payphone Complaint',
#  'Public Toilet',
#  'School Maintenance'}

# %%
set(df.descriptor)
# Out:
# {'Air Conditioning Problem',
#  'American Flag',
#  'Asbestos',
#  'Bent/Loose',
#  'Broken Fence',
#  'Broken Glass',
#  'Broken Lock',
#  'Broken Water Fountain',
#  'Broken Window',
#  'Cave-in',
#  'Coin or Card Did Not Register',
#  'Concrete Barrier',
#  'Crash Cushion Defect',
#  'Credit Card Stuck in Meter',
#  'Damaged Bench',
#  'Damaged Leg or Pole Bent',
#  'Damaged Other',
#  'Damaged Telephone',
#  'Damaged Toilet/Sink',
#  'Damaged or Leaking Roof',
#  'Damaged or Missing Ad Box',
#  'Dead Animal',
#  'Decorative Necklace Lighting',
#  'Dirt, Debris, Litter Complaint',
#  'Dirty/Graffiti',
#  'Fallen Debris from Bridge',
#  'Fence',
#  'Flooded',
#  'Garbage or Litter',
#  'Graffiti',
#  'Graffiti - Bridge',
#  'Graffiti - Highway',
#  'Graffiti or Vandalism',
#  'Graffiti/Litter on Phone',
#  'Grass/Weeds',
#  'Guard Rail - Bridge',
#  'Guard Rail - Highway',
#  'Heating Problem',
#  'High Grass',
#  'Highway Fence',
#  'Hours of Operation',
#  'Lack of Supplies',
#  'Leaky Roof',
#  'Lighting',
#  'Litter',
#  'Loose Plate',
#  'Lost Coin',
#  'Missing/Stump',
#  'New Automatic Public Toilet Request',
#  'No Dial Tone',
#  'No Receipt',
#  'Other School Condition',
#  'Out of Order',
#  'Painted Line/Marking',
#  'Parking Card Stuck in Meter',
#  'Phone Blocking Sidewalk',
#  'Plumbing Problem',
#  'Poison Ivy',
#  'Police Report Not Requested',
#  'Police Report Requested',
#  'Pothole',
#  'Pothole - Highway',
#  'Relocation of Parking Meter',
#  'Rodent Sighting',
#  'Rodents/Mice',
#  'Rough Pavement',
#  'Sign Blocked by Tree',
#  'Sign Missing or Defective',
#  'Snow Removal Requested',
#  'Snow on Overpass',
#  'Snow or Ice',
#  'Snow/Ice',
#  'Structure - Indoors',
#  'Structure - Outdoors',
#  'Timer Defect - Fast/Fail',
#  'Unclean Condition',
#  'Unsafe Worksite',
#  'Unsecured Facility'}

# %%
# Step 1
cd_counts = df.groupby('complaint_type').size().reset_index(name='descriptor').sort_values('descriptor', ascending=False)

# %%
# Graffiti is present in either the complaint_type value or descriptor value.
cd_counts
# Out:
#                complaint_type  descriptor
# 3                    Graffiti       24986
# 5     Maintenance or Facility       17665
# 1        Broken Parking Meter       14210
# 4           Highway Condition        3543
# 8          School Maintenance        2372
# 2  Bus Stop Shelter Complaint         990
# 0            Bridge Condition         392
# 6   Public Payphone Complaint         378
# 7               Public Toilet          41

# %%
cd_counts.head()
# Out:
#             complaint_type  descriptor
# 3                 Graffiti       24986
# 5  Maintenance or Facility       17665
# 1     Broken Parking Meter       14210
# 4        Highway Condition        3543
# 8       School Maintenance        2372

# %%
# df['graffiti_flag']= df.apply(recode_graffitti_count, axis=1)
def recode_graffiti_counts(row):
  if pd.notnull(row.descriptor):
    if 'graffiti' in row.complaint_type.lower():
      return True 
    elif 'graffiti' in row.descriptor.lower():
      return True
    else:
      return False

# %%
type(recode_graffiti_counts)
# Out:
# function

# %%
# Step 2
df['graffiti_flag'] = df.apply(recode_graffiti_counts, axis=1)

# %%
df.head(10)
# Out:
#    Unnamed: 0  Unnamed: 0.1  unique_key            created_date  \
# 0         238           238    39887282  08/01/2018 01:42:01 AM
# 1         353           353    39889407  08/01/2018 03:20:07 AM
# 2         403           403    39893067  08/01/2018 04:19:15 AM
# 3         655           655    39890578  08/01/2018 07:32:33 AM
# 4         658           658    39896325  08/01/2018 07:33:12 AM
# 5         661           661    39895587  08/01/2018 07:34:44 AM
# 6         713           713    39890857  08/01/2018 07:53:38 AM
# 7         789           789    39894929  08/01/2018 08:07:49 AM
# 8         860           860    39897352  08/01/2018 08:21:08 AM
# 9         876           876    39891938  08/01/2018 08:24:41 AM
#
#               closed_date agency                         agency_name  \
# 0  08/14/2018 02:42:12 PM    DPR  Department of Parks and Recreation
# 1  08/23/2018 11:15:00 AM    DPR  Department of Parks and Recreation
# 2  08/02/2018 08:19:55 AM    DPR  Department of Parks and Recreation
# 3  08/16/2018 10:28:38 AM    DPR  Department of Parks and Recreation
# 4  09/04/2018 05:38:02 PM    DPR  Department of Parks and Recreation
# 5  08/10/2018 01:45:07 PM    DPR  Department of Parks and Recreation
# 6  08/08/2018 04:21:55 PM    DPR  Department of Parks and Recreation
# 7  08/07/2018 12:20:24 PM    DOT        Department of Transportation
# 8                     NaN   DSNY            Department of Sanitation
# 9  08/30/2018 12:00:00 AM   DSNY            Department of Sanitation
#
#             complaint_type                     descriptor    location_type  \
# 0  Maintenance or Facility           Structure - Outdoors             Park
# 1  Maintenance or Facility              Garbage or Litter             Park
# 2  Maintenance or Facility             Hours of Operation             Park
# 3  Maintenance or Facility              Garbage or Litter             Park
# 4  Maintenance or Facility              Garbage or Litter             Park
# 5  Maintenance or Facility             Unsecured Facility             Park
# 6  Maintenance or Facility                    Grass/Weeds  Street/Curbside
# 7     Broken Parking Meter  Coin or Card Did Not Register           Street
# 8                 Graffiti                       Graffiti              NaN
# 9                 Graffiti                       Graffiti        Mixed Use
#
#    incident_zip   incident_address    street_name cross_street_1  \
# 0       10003.0                NaN            NaN            NaN
# 1       11434.0                NaN            NaN            NaN
# 2       11206.0                NaN            NaN            NaN
# 3       11691.0                NaN            NaN            NaN
# 4       11355.0                NaN            NaN            NaN
# 5       10033.0                NaN            NaN            NaN
# 6       11429.0         211 STREET     211 STREET     104 AVENUE
# 7       10461.0                NaN            NaN            NaN
# 8           NaN         141 141 ST         141 ST            NaN
# 9       11237.0  237 IRVING AVENUE  IRVING AVENUE            NaN
#
#   cross_street_2 intersection_street_1 intersection_street_2  address_type  \
# 0            NaN                   NaN                   NaN           NaN
# 1            NaN     BAISLEY BOULEVARD     MERRICK BOULEVARD  INTERSECTION
# 2            NaN                   NaN                   NaN           NaN
# 3            NaN                   NaN                   NaN           NaN
# 4            NaN                   NaN                   NaN           NaN
# 5            NaN                   NaN                   NaN           NaN
# 6  HOLLIS AVENUE                   NaN                   NaN     BLOCKFACE
# 7            NaN    WESTCHESTER AVENUE       COLONIAL AVENUE  INTERSECTION
# 8            NaN                   NaN                   NaN       ADDRESS
# 9            NaN                   NaN                   NaN       ADDRESS
#
#              city landmark facility_type  status                due_date  \
# 0        NEW YORK      NaN           NaN  Closed  08/15/2018 01:42:01 AM
# 1         JAMAICA      NaN           NaN  Closed  08/04/2018 03:20:07 AM
# 2        BROOKLYN      NaN           NaN  Closed  08/04/2018 04:19:15 AM
# 3    FAR ROCKAWAY      NaN           NaN  Closed  08/04/2018 07:32:33 AM
# 4        FLUSHING      NaN           NaN  Closed  08/04/2018 07:33:12 AM
# 5        NEW YORK      NaN           NaN  Closed  08/04/2018 07:34:44 AM
# 6  QUEENS VILLAGE      NaN           NaN  Closed  08/15/2018 07:53:38 AM
# 7           BRONX      NaN           NaN  Closed  08/21/2018 08:07:49 AM
# 8             NaN      NaN           NaN    Open                     NaN
# 9        BROOKLYN      NaN           NaN  Closed  09/06/2018 10:04:56 AM
#
#                               resolution_description  \
# 0  The Department of Parks and Recreation has com...
# 1  The Service Request submitted did not have suf...
# 2  The Department of Parks and Recreation has com...
# 3  The Department of Parks and Recreation has com...
# 4  The condition was inspected and it was determi...
# 5  The Department of Parks and Recreation has com...
# 6  The Service Request submitted did not have suf...
# 7  General maintenance and cleaning is on a regul...
# 8                                                NaN
# 9  The City has removed the graffiti from this pr...
#
#   resolution_action_updated_date     community_board           bbl  \
# 0         08/14/2018 02:42:12 PM       0 Unspecified           NaN
# 1         08/23/2018 11:15:00 AM           12 QUEENS           NaN
# 2         08/02/2018 08:19:55 AM         01 BROOKLYN           NaN
# 3         08/16/2018 10:28:38 AM           14 QUEENS           NaN
# 4         09/04/2018 05:38:02 PM           07 QUEENS           NaN
# 5         08/10/2018 01:44:53 PM        12 MANHATTAN           NaN
# 6         08/08/2018 04:21:55 PM           13 QUEENS           NaN
# 7         08/07/2018 12:20:24 PM            10 BRONX           NaN
# 8         08/01/2018 08:21:08 AM  Unspecified QUEENS           NaN
# 9         09/20/2018 03:18:01 PM         04 BROOKLYN  3.032900e+09
#
#        borough  x_coordinate_(state_plane)  y_coordinate_(state_plane)  \
# 0  Unspecified                         NaN                         NaN
# 1       QUEENS                   1048111.0                    188479.0
# 2     BROOKLYN                         NaN                         NaN
# 3       QUEENS                         NaN                         NaN
# 4       QUEENS                         NaN                         NaN
# 5    MANHATTAN                         NaN                         NaN
# 6       QUEENS                   1054213.0                    198447.0
# 7        BRONX                   1031884.0                    249950.0
# 8       QUEENS                         NaN                         NaN
# 9     BROOKLYN                   1007216.0                    194542.0
#
#   open_data_channel_type                        park_facility_name  \
# 0                  PHONE                                First Park
# 1                  PHONE                               Unspecified
# 2                 MOBILE                            Ten Eyck Plaza
# 3                  PHONE                     Westbourne Playground
# 4                 MOBILE                          Maple Playground
# 5                  PHONE  Fort Tryon Park - Anne Loftus Playground
# 6                  PHONE                               Unspecified
# 7                  PHONE                               Unspecified
# 8                UNKNOWN                               Unspecified
# 9                UNKNOWN                               Unspecified
#
#   park_borough  vehicle_type  taxi_company_borough  taxi_pick_up_location  \
# 0  Unspecified           NaN                   NaN                    NaN
# 1       QUEENS           NaN                   NaN                    NaN
# 2     BROOKLYN           NaN                   NaN                    NaN
# 3       QUEENS           NaN                   NaN                    NaN
# 4       QUEENS           NaN                   NaN                    NaN
# 5    MANHATTAN           NaN                   NaN                    NaN
# 6       QUEENS           NaN                   NaN                    NaN
# 7        BRONX           NaN                   NaN                    NaN
# 8       QUEENS           NaN                   NaN                    NaN
# 9     BROOKLYN           NaN                   NaN                    NaN
#
#   bridge_highway_name bridge_highway_direction road_ramp  \
# 0                 NaN                      NaN       NaN
# 1                 NaN                      NaN       NaN
# 2                 NaN                      NaN       NaN
# 3                 NaN                      NaN       NaN
# 4                 NaN                      NaN       NaN
# 5                 NaN                      NaN       NaN
# 6                 NaN                      NaN       NaN
# 7                 NaN                      NaN       NaN
# 8                 NaN                      NaN       NaN
# 9                 NaN                      NaN       NaN
#
#   bridge_highway_segment   latitude  longitude  \
# 0                    NaN        NaN        NaN
# 1                    NaN  40.683778 -73.769744
# 2                    NaN        NaN        NaN
# 3                    NaN        NaN        NaN
# 4                    NaN        NaN        NaN
# 5                    NaN        NaN        NaN
# 6                    NaN  40.711091 -73.747639
# 7                    NaN  40.852601 -73.827816
# 8                    NaN        NaN        NaN
# 9                    NaN  40.700620 -73.917173
#
#                                    location  graffiti_flag
# 0                                       NaN          False
# 1   (40.68377771085733, -73.76974413109498)          False
# 2                                       NaN          False
# 3                                       NaN          False
# 4                                       NaN          False
# 5                                       NaN          False
# 6  (40.711091308732435, -73.74763946439865)          False
# 7  (40.852601460220185, -73.82781602326443)          False
# 8                                       NaN           True
# 9   (40.70061981717157, -73.91717344071574)           True

# %%
graffiti_flag = df.groupby('graffiti_flag').size().reset_index(name= 'count')
graffiti_flag
# Out:
#    graffiti_flag  count
# 0          False  38206
# 1           True  26371

# %%
# Step 3
# Only contains graffiti_flag is true
df_graffiti = df.loc[df['graffiti_flag'] == True]

# %%
df_graffiti.head()
# Out:
#     Unnamed: 0  Unnamed: 0.1  unique_key            created_date  \
# 8          860           860    39897352  08/01/2018 08:21:08 AM
# 9          876           876    39891938  08/01/2018 08:24:41 AM
# 10         964           964    39897349  08/01/2018 08:40:34 AM
# 12        1007          1007    39893314  08/01/2018 08:47:45 AM
# 13        1013          1013    39897422  08/01/2018 08:49:15 AM
#
#                closed_date agency               agency_name complaint_type  \
# 8                      NaN   DSNY  Department of Sanitation       Graffiti
# 9   08/30/2018 12:00:00 AM   DSNY  Department of Sanitation       Graffiti
# 10  08/23/2018 12:00:00 AM   DSNY  Department of Sanitation       Graffiti
# 12  08/20/2018 12:00:00 AM   DSNY  Department of Sanitation       Graffiti
# 13  08/28/2018 12:00:00 AM   DSNY  Department of Sanitation       Graffiti
#
#    descriptor location_type  incident_zip      incident_address  \
# 8    Graffiti           NaN           NaN            141 141 ST
# 9    Graffiti     Mixed Use       11237.0     237 IRVING AVENUE
# 10   Graffiti   Residential       10467.0  345 EAST  205 STREET
# 12   Graffiti     Mixed Use       11220.0         5506 5 AVENUE
# 13   Graffiti     Mixed Use       11237.0       884 HART STREET
#
#          street_name cross_street_1 cross_street_2 intersection_street_1  \
# 8             141 ST            NaN            NaN                   NaN
# 9      IRVING AVENUE            NaN            NaN                   NaN
# 10  EAST  205 STREET            NaN            NaN                   NaN
# 12          5 AVENUE            NaN            NaN                   NaN
# 13       HART STREET            NaN            NaN                   NaN
#
#    intersection_street_2 address_type      city landmark facility_type  \
# 8                    NaN      ADDRESS       NaN      NaN           NaN
# 9                    NaN      ADDRESS  BROOKLYN      NaN           NaN
# 10                   NaN      ADDRESS     BRONX      NaN           NaN
# 12                   NaN      ADDRESS  BROOKLYN      NaN           NaN
# 13                   NaN      ADDRESS  BROOKLYN      NaN           NaN
#
#     status                due_date  \
# 8     Open                     NaN
# 9   Closed  09/06/2018 10:04:56 AM
# 10  Closed  09/06/2018 10:04:56 AM
# 12  Closed  09/06/2018 10:04:56 AM
# 13  Closed  09/06/2018 10:04:56 AM
#
#                                resolution_description  \
# 8                                                 NaN
# 9   The City has removed the graffiti from this pr...
# 10  The City has removed the graffiti from this pr...
# 12  The City has removed the graffiti from this pr...
# 13  The City has removed the graffiti from this pr...
#
#    resolution_action_updated_date     community_board           bbl   borough  \
# 8          08/01/2018 08:21:08 AM  Unspecified QUEENS           NaN    QUEENS
# 9          09/20/2018 03:18:01 PM         04 BROOKLYN  3.032900e+09  BROOKLYN
# 10         09/13/2018 04:19:12 PM            07 BRONX  2.033500e+09     BRONX
# 12         09/13/2018 04:19:12 PM         07 BROOKLYN  3.008310e+09  BROOKLYN
# 13         09/13/2018 04:19:12 PM         04 BROOKLYN  3.032360e+09  BROOKLYN
#
#     x_coordinate_(state_plane)  y_coordinate_(state_plane)  \
# 8                          NaN                         NaN
# 9                    1007216.0                    194542.0
# 10                   1018509.0                    257554.0
# 12                    980544.0                    173249.0
# 13                   1005915.0                    195340.0
#
#    open_data_channel_type park_facility_name park_borough  vehicle_type  \
# 8                 UNKNOWN        Unspecified       QUEENS           NaN
# 9                 UNKNOWN        Unspecified     BROOKLYN           NaN
# 10                UNKNOWN        Unspecified        BRONX           NaN
# 12                UNKNOWN        Unspecified     BROOKLYN           NaN
# 13                UNKNOWN        Unspecified     BROOKLYN           NaN
#
#     taxi_company_borough  taxi_pick_up_location bridge_highway_name  \
# 8                    NaN                    NaN                 NaN
# 9                    NaN                    NaN                 NaN
# 10                   NaN                    NaN                 NaN
# 12                   NaN                    NaN                 NaN
# 13                   NaN                    NaN                 NaN
#
#    bridge_highway_direction road_ramp bridge_highway_segment   latitude  \
# 8                       NaN       NaN                    NaN        NaN
# 9                       NaN       NaN                    NaN  40.700620
# 10                      NaN       NaN                    NaN  40.873534
# 12                      NaN       NaN                    NaN  40.642204
# 13                      NaN       NaN                    NaN  40.702813
#
#     longitude                                 location  graffiti_flag
# 8         NaN                                      NaN           True
# 9  -73.917173  (40.70061981717157, -73.91717344071574)           True
# 10 -73.876124  (40.87353414980636, -73.87612406980227)           True
# 12 -74.013354  (40.64220432954161, -74.01335393443593)           True
# 13 -73.921863  (40.70281342017164, -73.92186290937498)           True

# %%
# Step 4
df_graffiti.groupby('community_board')

# %%
# this is wrong because I redefined graffiti_flag
graffiti_flag = df.groupby('community_board').size().nlargest().reset_index(name= 'count')
graffiti_flag
# Out:
#   community_board  count
# 0   0 Unspecified   8584
# 1    03 MANHATTAN   2511
# 2     01 BROOKLYN   2495
# 3     03 BROOKLYN   1715
# 4     04 BROOKLYN   1567

# %%
# Group dataframe df_graffiti to get the count of requests per community_board
df_graffiti.groupby('community_board').size().reset_index(name='count')
# Out:
#               community_board  count
# 0               0 Unspecified    540
# 1                    01 BRONX    311
# 2                 01 BROOKLYN   1797
# 3                01 MANHATTAN    146
# 4                   01 QUEENS    572
# 5            01 STATEN ISLAND    255
# 6                    02 BRONX    243
# 7                 02 BROOKLYN    315
# 8                02 MANHATTAN    598
# 9                   02 QUEENS    219
# 10           02 STATEN ISLAND     42
# 11                   03 BRONX    320
# 12                03 BROOKLYN   1252
# 13               03 MANHATTAN   1593
# 14                  03 QUEENS    202
# 15           03 STATEN ISLAND     40
# 16                   04 BRONX    336
# 17                04 BROOKLYN   1429
# 18               04 MANHATTAN    306
# 19                  04 QUEENS    353
# 20                   05 BRONX    402
# 21                05 BROOKLYN    962
# 22               05 MANHATTAN    283
# 23                  05 QUEENS    219
# 24                   06 BRONX    446
# 25                06 BROOKLYN    401
# 26               06 MANHATTAN    162
# 27                  06 QUEENS     68
# 28                   07 BRONX    322
# 29                07 BROOKLYN    779
# 30               07 MANHATTAN    224
# 31                  07 QUEENS    350
# 32                   08 BRONX    127
# 33                08 BROOKLYN    505
# 34               08 MANHATTAN    273
# 35                  08 QUEENS    129
# 36                   09 BRONX    464
# 37                09 BROOKLYN    403
# 38               09 MANHATTAN    201
# 39                  09 QUEENS    470
# 40                   10 BRONX    150
# 41                10 BROOKLYN    268
# 42               10 MANHATTAN    266
# 43                  10 QUEENS    202
# 44                   11 BRONX    267
# 45                11 BROOKLYN    474
# 46               11 MANHATTAN    229
# 47                  11 QUEENS     57
# 48                   12 BRONX    426
# 49                12 BROOKLYN    532
# 50               12 MANHATTAN    459
# 51                  12 QUEENS    539
# 52                13 BROOKLYN    196
# 53                  13 QUEENS    142
# 54                14 BROOKLYN    532
# 55                  14 QUEENS     91
# 56                15 BROOKLYN    329
# 57                16 BROOKLYN    371
# 58                17 BROOKLYN    480
# 59                18 BROOKLYN    410
# 60                   26 BRONX      5
# 61                   27 BRONX      4
# 62                   28 BRONX      2
# 63                55 BROOKLYN      2
# 64               64 MANHATTAN      1
# 65                  81 QUEENS      5
# 66          Unspecified BRONX    615
# 67       Unspecified BROOKLYN    591
# 68      Unspecified MANHATTAN    405
# 69         Unspecified QUEENS    254
# 70  Unspecified STATEN ISLAND      8

# %%
# Group dataframe df_graffiti to get the count of requests per community_board and use nlargest() 
# 01 Brooklyn has the largest count 1797
df_graffiti.groupby('community_board').size().nlargest().reset_index(name= 'count')
# Out:
#   community_board  count
# 0     01 BROOKLYN   1797
# 1    03 MANHATTAN   1593
# 2     04 BROOKLYN   1429
# 3     03 BROOKLYN   1252
# 4     05 BROOKLYN    962
